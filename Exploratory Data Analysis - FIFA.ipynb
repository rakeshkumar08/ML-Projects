# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv('D:/EDA/Fifa.csv')

# %%
pd.set_option('display.max_columns',60)
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Dropping unnecessary columns:

# %%
df.drop(columns=['ID','Photo','Flag','Club Logo','Preferred Foot','Body Type','Jersey Number','Crossing',
                 'Finishing','HeadingAccuracy','ShortPassing','Volleys','Dribbling','Curve','FKAccuracy',
                 'LongPassing','BallControl','Acceleration','SprintSpeed','Agility','Reactions','Balance',
                'ShotPower','Jumping','Stamina','Strength','LongShots','Aggression','Interceptions','Positioning',
                'Vision','Penalties','Composure','Marking','StandingTackle','SlidingTackle','GKDiving','GKHandling',
                'GKKicking','GKPositioning','GKReflexes'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage  International Reputation  Weak Foot  \
# 0         FC Barcelona  €110.5M  €565K                       5.0        4.0
# 1             Juventus     €77M  €405K                       5.0        4.0
# 2  Paris Saint-Germain  €118.5M  €290K                       5.0        5.0
# 3    Manchester United     €72M  €260K                       4.0        3.0
# 4      Manchester City    €102M  €355K                       4.0        5.0
#
#    Skill Moves       Work Rate Position        Joined Loaned From  \
# 0          4.0  Medium/ Medium       RF   Jul 1, 2004         NaN
# ...

# %%
print('No of rows:',df.shape[0])
print('No of columns:',df.shape[1])
# Out:
# No of rows: 18207
# No of columns: 19

# %% [markdown]
# ### Renaming Columns

# %%
df.columns = df.columns.str.replace(' ','_')
df.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'International_Reputation', 'Weak_Foot', 'Skill_Moves',
#        'Work_Rate', 'Position', 'Joined', 'Loaned_From',
#        'Contract_Valid_Until', 'Height', 'Weight', 'Release_Clause'],
#       dtype='object')

# %% [markdown]
# ### Replacing values

# %%
df['Height'] = df['Height'].replace({"'":'.'},regex=True).astype(float)
df['Weight'] = df['Weight'].replace({'lbs':' '},regex=True).astype(float)
df['Contract_Valid_Until'] = pd.to_datetime(df['Contract_Valid_Until'])
df['Joined'] = pd.to_datetime(df['Joined'])
df['Joined'] = df['Joined'].fillna( df['Joined'].mean())
df['Joined'] = df['Joined'].dt.year

# %%
def Change_Value(x):
    x = str(x).replace('€', '')
    if('M' in str(x)):
        x = str(x).replace('M', '')
        x = float(x) * 1000000
    elif('K' in str(x)):
        x = str(x).replace('K', '')
        x = float(x) * 1000
    return float(x)

df['Value'] = df['Value'].apply(Change_Value)

# %%
def Change_Wage(x):
    x = str(x).replace('€','')
    if('M' in str(x)):
        x = str(x).replace('M','')
        x = float(x) * 1000000
    elif('K' in str(x)):
        x = str(x).replace('K','')
        x = float(x) * 1000
    return float(x)

df['Wage'] = df['Wage'].apply(Change_Wage)

# %%
def Change_Release_clause(x):
    x = str(x).replace('€','')
    if('M' in str(x)):
        x = str(x).replace('M','')
        x = float(x) * 1000000
    elif('K' in str(x)):
        x = str(x).replace('K','')
        x = float(x) * 1000
    return float(x)

df['Release_Clause'] = df['Release_Clause'].apply(Change_Release_clause)

# %%
df.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club        Value      Wage  International_Reputation  \
# 0         FC Barcelona  110500000.0  565000.0                       5.0
# 1             Juventus   77000000.0  405000.0                       5.0
# 2  Paris Saint-Germain  118500000.0  290000.0                       5.0
# 3    Manchester United   72000000.0  260000.0                       4.0
# 4      Manchester City  102000000.0  355000.0                       4.0
#
#    Weak_Foot  Skill_Moves       Work_Rate Position  Joined Loaned_From  \
# 0        4.0          4.0  Medium/ Medium       RF    2004         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18207 non-null  object
#  1   Age                       18207 non-null  int64
#  2   Nationality               18207 non-null  object
#  3   Overall                   18207 non-null  int64
#  4   Potential                 18207 non-null  int64
#  5   Club                      17966 non-null  object
#  6   Value                     18207 non-null  float64
#  7   Wage                      18207 non-null  float64
#  8   International_Reputation  18159 non-null  float64
#  9   Weak_Foot                 18159 non-null  float64
#  10  Skill_Moves               18159 non-null  float64
#  11  Work_Rate                 18159 non-null  object
#  12  Position                  18147 non-null  object
# ...

# %%
df.dtypes.value_counts()
# Out:
# float64           8
# object            6
# int64             4
# datetime64[ns]    1
# dtype: int64

# %%
df.describe()
# Out:
#                 Age       Overall     Potential         Value           Wage  \
# count  18207.000000  18207.000000  18207.000000  1.820700e+04   18207.000000
# mean      25.122206     66.238699     71.307299  2.410696e+06    9731.312133
# std        4.669943      6.908930      6.136496  5.594933e+06   21999.290406
# min       16.000000     46.000000     48.000000  0.000000e+00       0.000000
# 25%       21.000000     62.000000     67.000000  3.000000e+05    1000.000000
# 50%       25.000000     66.000000     71.000000  6.750000e+05    3000.000000
# 75%       28.000000     71.000000     75.000000  2.000000e+06    9000.000000
# max       45.000000     94.000000     95.000000  1.185000e+08  565000.000000
#
#        International_Reputation     Weak_Foot   Skill_Moves        Joined  \
# count              18159.000000  18159.000000  18159.000000  18207.000000
# mean                   1.113222      2.947299      2.361308   2016.420607
# ...

# %% [markdown]
# ## Missing values

# %%
def missing_check(data):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = ((df.isnull().sum()/df.isnull().count())*100).sort_values(ascending=False)
    missing_perc = pd.concat([total,percent],axis=1,keys=['total','percent'])
    return missing_perc
missing_check(df)
# Out:
#                           total    percent
# Loaned_From               16943  93.057615
# Release_Clause             1564   8.590103
# Contract_Valid_Until        289   1.587302
# Club                        241   1.323667
# Position                     60   0.329544
# Skill_Moves                  48   0.263635
# International_Reputation     48   0.263635
# Weight                       48   0.263635
# Weak_Foot                    48   0.263635
# Work_Rate                    48   0.263635
# Height                       48   0.263635
# Joined                        0   0.000000
# Wage                          0   0.000000
# Value                         0   0.000000
# Potential                     0   0.000000
# Overall                       0   0.000000
# Nationality                   0   0.000000
# Age                           0   0.000000
# Name                          0   0.000000

# %%
#Since loaned from column has 93% nan values we can drop it.
df = df.drop('Loaned_From',axis=1)

# %% [markdown]
# ### Remaining missing values

# %%
def missing_check(data):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = ((df.isnull().sum()/df.isnull().count())*100).sort_values(ascending=False)
    missing_perc = pd.concat([total,percent],axis=1,keys=['total','percent'])
    return missing_perc
missing_check(df).head(10)
# Out:
#                           total   percent
# Release_Clause             1564  8.590103
# Contract_Valid_Until        289  1.587302
# Club                        241  1.323667
# Position                     60  0.329544
# Skill_Moves                  48  0.263635
# Weight                       48  0.263635
# Weak_Foot                    48  0.263635
# International_Reputation     48  0.263635
# Work_Rate                    48  0.263635
# Height                       48  0.263635

# %%
df['Release_Clause'] = df['Release_Clause'].fillna(df['Release_Clause'].mean())
df['Contract_Valid_Until'] = df['Contract_Valid_Until'].fillna(df['Contract_Valid_Until'].mean())
df['Skill_Moves'] = df['Skill_Moves'].fillna(df['Skill_Moves'].mean())
df['Weight'] = df['Weight'].fillna(df['Weight'].mean())
df['Weak_Foot'] = df['Weak_Foot'].fillna(df['Weak_Foot'].mean())
df['International_Reputation'] = df['International_Reputation'].fillna(df['International_Reputation'].mean())
df['Height'] = df['Height'].fillna(df['Height'].mean())

# %%
df['Club'] = df['Club'].fillna(method='ffill')
df['Position'] = df['Position'].fillna(method='ffill')
df['Work_Rate'] = df['Work_Rate'].fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# Name                        0
# Age                         0
# Nationality                 0
# Overall                     0
# Potential                   0
# Club                        0
# Value                       0
# Wage                        0
# International_Reputation    0
# Weak_Foot                   0
# Skill_Moves                 0
# Work_Rate                   0
# Position                    0
# Joined                      0
# Contract_Valid_Until        0
# Height                      0
# Weight                      0
# Release_Clause              0
# dtype: int64

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# #### Nationality

# %%
plt.figure(figsize=(10,5))
df["Nationality"].value_counts().head(20).plot(kind='bar',color=['#FF6347','#3CB371','#800000','#1E90FF','#FFC0CB'])
plt.xlabel('Nationality')
plt.ylabel('Count')
plt.title('Nationality of players')
plt.show()

# %% [markdown]
# #### Observation:

# %% [markdown]
# Most of the players are from England, followed by Germany and Spain.

# %% [markdown]
# #### Position

# %%
plt.figure(figsize=(15,5))
df['Position'].value_counts().plot(kind='bar',color=['#000080','#FFD700','#228B22','#FF1493'])
plt.title('Count of Players Position')
plt.xlabel('Position')
plt.ylabel('Count')
plt.xticks(rotation=360)
plt.show()

# %% [markdown]
# #### Age

# %%
df["Age"].plot(kind='hist',color='#7CFC00',bins=15,edgecolor='black')
plt.title('Age distribution of players')
plt.xlabel('Age')
plt.show()

# %%
df['Age'].plot(kind='box')
plt.show()

# %% [markdown]
# #### Observation

# %% [markdown]
# Many players age are in the range 20-28. There are very few outliers present.

# %% [markdown]
# #### Weight

# %%
df["Weight"].plot(kind='hist',color='#DC143C',edgecolor='#FFFACD')
plt.title('Weight distribution of the players')
plt.xlabel('Weight')
plt.show()

# %%
df['Weight'].plot(kind='box')
plt.show()

# %% [markdown]
# #### Observation

# %% [markdown]
# The median weight is 160lbs. Majority of the players are in the weight range 150-180lbs. There are outliers present.

# %% [markdown]
# #### Height

# %%
df["Height"].value_counts().head(10).plot(kind='bar',color=['#FF1493','#D2691E','#3CB371'])
plt.title('Height of players')
plt.xlabel('Height')
plt.show()

# %% [markdown]
# #### Observation

# %% [markdown]
# Majority of the players are in the height of 5.9ft - 6.3ft.

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.scatterplot(x='Overall',y='Value',data=df,color='#6B8E23')
plt.title('Overall vs Value')
plt.show()

# %% [markdown]
# #### Observation

# %% [markdown]
# Until overall value of 75, the amount is not increasing much. But once the overall value is crossing the 80 mark
# you can see an exponential growth. Top players tend to have very high value amount.

# %%
sns.scatterplot(x='Overall',y='Wage',data=df,color='#800080')
plt.title('Overall vs Wage')
plt.show()

# %% [markdown]
# #### Observation

# %% [markdown]
# The wage tends to be below 100K till 70 and after that it increases exponentially with respect to the overall score. Top players tend to have very high wage. Ex: L.Messi,Neymar.Jr etc

# %%
sns.scatterplot(x='Overall',y='Release_Clause',data=df,color='#DC143C')
plt.title('Overall vs Release_Clause')
plt.show()

# %% [markdown]
# #### Observation

# %% [markdown]
# The release clause is high for players whose overall value is above 70 and keeps growing accordingly.

# %% [markdown]
# ## 1. Distribution Plot for Overall Rating of all players

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Overall'],bins=20,kde=True,color="#191970",
             hist_kws={"linewidth":3,'color':'#3CB371','edgecolor':'black'},kde_kws={'linewidth':'5'})
plt.title('Distribution Plot for Overall Rating of all players')
plt.show()

# %%
print('Skewness for Overall:',df['Overall'].skew())
print('Kurtosis for Overall:',df['Overall'].kurt())
# Out:
# Skewness for Overall: 0.06718492227833812
# Kurtosis for Overall: 0.09656866702634614

# %% [markdown]
# #### Observation:

# %% [markdown]
# It is almost close to a normal distribution. It has very less skewness and peakedness. Most of the players fall under the range 60-70. range.

# %% [markdown]
# ## 2. Pair plot

# %%
df1 = df[['Overall', 'Value', 'Wage', 'International_Reputation', 'Height', 'Weight', 'Release_Clause']]

# %%
df1.head()
# Out:
#    Overall        Value      Wage  International_Reputation  Height  Weight  \
# 0       94  110500000.0  565000.0                       5.0    5.70   159.0
# 1       94   77000000.0  405000.0                       5.0    6.20   183.0
# 2       92  118500000.0  290000.0                       5.0    5.90   150.0
# 3       91   72000000.0  260000.0                       4.0    6.40   168.0
# 4       91  102000000.0  355000.0                       4.0    5.11   154.0
#
#    Release_Clause
# 0     226500000.0
# 1     127100000.0
# 2     228100000.0
# 3     138600000.0
# 4     196400000.0

# %%
sns.pairplot(data=df1)
plt.show()

# %% [markdown]
# ## 3. Generate a table containing the top 20 players ranked by Overall score and whose contract expires in 2020.

# %%
df['Contract_Valid_Until'] = pd.to_datetime(df['Contract_Valid_Until']).dt.to_period('Y')

# %%
df2 = df[df['Contract_Valid_Until']=='2020'].sort_values(by='Overall',ascending=False)[:20].reset_index()
df2
# Out:
#     index             Name  Age Nationality  Overall  Potential  \
# 0       3           De Gea   27       Spain       91         93
# 1       6        L. Modrić   32     Croatia       91         91
# 2       8     Sergio Ramos   32       Spain       91         91
# 3       5        E. Hazard   27     Belgium       91         91
# 4      13      David Silva   32       Spain       90         90
# 5      21        E. Cavani   31     Uruguay       89         89
# 6      24     G. Chiellini   33       Italy       89         89
# 7      31       C. Eriksen   26     Denmark       88         91
# 8      39     Thiago Silva   33      Brazil       88         88
# 9      50       D. Mertens   31     Belgium       87         87
# 10     52        M. Hamšík   30    Slovakia       87         87
# 11     49       Jordi Alba   29       Spain       87         87
# 12     46         K. Navas   31  Costa Rica       87         87
# 13     64      Alex Sandro   27      Brazil       86         86
# ...

# %% [markdown]
# ### a) What would the average wage for this set of players be?

# %%
print('The average wage for this set of players:',df2['Wage'].mean())
# Out:
# The average wage for this set of players: 205450.0

# %% [markdown]
# ### b) What is the average age?

# %%
print('The average age for this set of players:',df2['Age'].mean())
# Out:
# The average age for this set of players: 30.65

# %% [markdown]
# ### c) Is there a correlation between the Overall rating and Value for these players?

# %%
plt.subplots(figsize=(10,6))
sns.heatmap(df2.corr()[(df2.corr()>0.5)|(df2.corr()<-0.5)],annot=True,cmap='PiYG')
plt.show()

# %% [markdown]
# #### Observation

# %% [markdown]
# Yes, Overall and Value are highly correlated to each other for these players with a value of 0.79.

# %% [markdown]
# ### Generate table containing the top 5 players by Overall rating for each unique position

# %%
position_df = df.groupby(by='Position')['Name','Position','Overall'].head(5)
top_5 = position_df.sort_values(by=['Position','Overall'],ascending=(True,False))

# %%
pd.set_option('display.max_rows',135)
top_5
# Out:
#                      Name Position  Overall
# 17           A. Griezmann      CAM       89
# 31             C. Eriksen      CAM       88
# 61        Roberto Firmino      CAM       86
# 66              T. Müller      CAM       86
# 74                M. Özil      CAM       86
# 12               D. Godín       CB       90
# 42              S. Umtiti       CB       87
# 73             M. Benatia       CB       86
# 89            N. Otamendi       CB       85
# 102                 Naldo       CB       85
# 20        Sergio Busquets      CDM       89
# 27               Casemiro      CDM       88
# 72              M. Pjanić      CDM       86
# 75            Fernandinho      CDM       86
# 118               Fabinho      CDM       84
# 271          Luis Alberto       CF       82
# 293           S. Giovinco       CF       82
# 350              A. Milik       CF       81
# 382             L. Stindl       CF       81
# 407               Raffael       CF       81
# ...

# %% [markdown]
# ### Are there any players appearing in more than one Table? Please point out such players.

# %%
a = top_5["Name"].value_counts()
a[a>1]
# Out:
# Series([], Name: Name, dtype: int64)

# %% [markdown]
# There are no players appearing more than once in the table.

# %% [markdown]
# ### Average wage one can expect to pay for the top 5 in every position

# %%
wage_df = df.groupby('Position')
b = wage_df.mean()['Wage']
wage_mean = pd.DataFrame(b)
wage_mean.sort_values(by='Wage',ascending=False)
# Out:
#                   Wage
# Position
# RF        52687.500000
# LF        44666.666667
# LAM       26142.857143
# RAM       19095.238095
# LS        15260.869565
# RW        14432.432432
# RCM       14404.092072
# RS        14379.310345
# LCM       14131.645570
# LW        13068.241470
# RCB       12688.821752
# RDM       12149.193548
# LDM       11860.082305
# LCB       11498.456790
# CAM       10218.978102
# CF        10216.216216
# ST         9928.969359
# LM         9656.621005
# RM         9515.527950
# CDM        9315.400844
# LWB        9076.923077
# RB         8604.182804
# RWB        8597.701149
# LB         8467.930029
# CM         8334.767025
# CB         7700.393479
# GK         6797.237296
